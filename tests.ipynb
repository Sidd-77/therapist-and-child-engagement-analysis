# %%
import cv2
from deepface import DeepFace
# Out:
# 2024-04-09 00:55:52.799153: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-09 00:55:52.804122: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-09 00:55:52.858461: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-09 00:55:53.775941: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
import cv2
from deepface import DeepFace

# Load the cascade
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

def process_frame(frame):
    # Convert to grayscale
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Detect faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    faces = faces[:2]

    for (x, y, w, h) in faces:
        # Extract face
        face = frame[y:y+h, x:x+w]

        # Analyze emotions
        results = DeepFace.analyze(face, actions=['emotion'], enforce_detection=False)

        # Get the result for the first face
        result = results[0]

        # Display emotions
        cv2.putText(frame, result['dominant_emotion'], (x, y), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    return frame

# Read video file
cap = cv2.VideoCapture('videos/2.mp4')

while(cap.isOpened()):
    ret, frame = cap.read()

    if ret:
        # Process frame
        frame = process_frame(frame)

        # Display frame
        cv2.imshow('Video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 40
#      36 ret, frame = cap.read()
#      38 if ret:
#      39     # Process frame
# ---> 40     frame = process_frame(frame)
#      42     # Display frame
#      43     cv2.imshow('Video', frame)
#
# Cell In[3], line 12, in process_frame(frame)
#       9 gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      11 # Detect faces
# ---> 12 faces = face_cascade.detectMultiScale(gray, 1.1, 4)
#      14 faces = faces[:2]
#      16 for (x, y, w, h) in faces:
#      17     # Extract face
#
# KeyboardInterrupt:

# %%
from mtcnn import MTCNN

# Initialize the MTCNN model
detector = MTCNN()

def process_frame2(frame):
    # Detect faces
    faces = detector.detect_faces(frame)

    for face in faces:
        # Extract bounding box and keypoints
        x, y, w, h = face['box']
        keypoints = face['keypoints']

        # Extract face
        face_img = frame[y:y+h, x:x+w]

        # Analyze emotions
        results = DeepFace.analyze(face_img, actions=['emotion'], enforce_detection=False)

        # Get the result for the first face
        result = results[0]

        # Display emotions
        cv2.putText(frame, result['dominant_emotion'], (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

        # Draw rectangle around the face
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

    return frame

# %%
# Read video file
cap = cv2.VideoCapture('videos/1.mp4')
frame_count = 0

while(cap.isOpened()):
    ret, frame = cap.read()

    if ret:
        frame_count += 1

        # Process every 10th frame
        if frame_count % 10 == 0:
            # Detect faces
            faces = detector.detect_faces(frame)

            for face in faces:
                # Extract bounding box and keypoints
                x, y, w, h = face['box']
                keypoints = face['keypoints']

                # Extract face
                face_img = frame[y:y+h, x:x+w]

                # Analyze emotions
                results = DeepFace.analyze(face_img, actions=['emotion'], enforce_detection=False)

                # Get the result for the first face
                result = results[0]

                # Display emotions
                cv2.putText(frame, result['dominant_emotion'], (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                # Draw rectangle around the face
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

            # Display frame
            cv2.imshow('Video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 74ms/step
# ...
# ...
# 14/14 [==============================] - 0s 5ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 14
#      11 # Process every 10th frame
#      12 if frame_count % 10 == 0:
#      13     # Detect faces
# ---> 14     faces = detector.detect_faces(frame)
#      16     for face in faces:
#      17         # Extract bounding box and keypoints
#      18         x, y, w, h = face['box']
#
# File ~/therapist-and-child-engagement-analysis/.venv/lib/python3.11/site-packages/mtcnn/mtcnn.py:300, in MTCNN.detect_faces(self, img)
#     298 # We pipe here each of the stages
#     299 for stage in stages:
# --> 300     result = stage(img, result[0], result[1])
#     302 [total_boxes, points] = result
#     304 bounding_boxes = []
#
# ...

# %%
# Initialize dictionary to store emotion counts
emotion_counts = {}
cap = cv2.VideoCapture('videos/3.mp4')
frame_count = 0
from mtcnn import MTCNN

# Initialize the MTCNN model
detector = MTCNN()


while(cap.isOpened()):
    ret, frame = cap.read()

    if ret:
        frame_count += 1

        # Process every 10th frame
        if frame_count % 10 == 0:
            # Detect faces
            faces = detector.detect_faces(frame)

            for i, face in enumerate(faces):
                # Extract bounding box and keypoints
                x, y, w, h = face['box']
                keypoints = face['keypoints']

                # Extract face
                face_img = frame[y:y+h, x:x+w]

                # Analyze emotions
                results = DeepFace.analyze(face_img, actions=['emotion'], enforce_detection=False)

                for result in results:
                    dominant_emotion = result['dominant_emotion']
                    # rest of your code

                # Update emotion count
                if dominant_emotion in emotion_counts:
                    emotion_counts[dominant_emotion] += 1
                else:
                    emotion_counts[dominant_emotion] = 1

                # Display dominant emotion
                cv2.putText(frame, dominant_emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

                # Draw rectangle around the face
                cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

            # Display frame
            cv2.imshow('Video', frame)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

cap.release()
cv2.destroyAllWindows()

# Print emotion counts
for emotion, count in emotion_counts.items():
    print(f'{emotion}: {count}')
# Out:
# ...
# 1/1 [==============================] - 0s 385ms/step
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in "/home/sidd/therapist-and-child-engagement-analysis/.venv/lib/python3.11/site-packages/cv2/qt/plugins"
# ...
# 1/1 [==============================] - 0s 28ms/step
# happy: 28
# sad: 28
# surprise: 1
# neutral: 51
# fear: 13
# angry: 7

# %%
from deepface import DeepFace
# Out:
# 2024-04-09 09:39:10.566490: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-09 09:39:10.570226: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-09 09:39:10.617113: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-09 09:39:11.668178: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
result = DeepFace.analyze(img_path="images/6.png", actions=['emotion'])

# %%
import json
print(json.dumps(result, indent=2))
# Out:
# [
#   {
#     "emotion": {
#       "angry": 0.8813349530100822,
#       "disgust": 0.002550041062931996,
#       "fear": 1.297361496835947,
#       "happy": 2.6911363005638123,
#       "sad": 4.867195710539818,
#       "surprise": 0.0019527209587977268,
#       "neutral": 90.25847315788269
#     },
#     "dominant_emotion": "neutral",
#     "region": {
#       "x": 173,
#       "y": 110,
#       "w": 119,
#       "h": 119,
#       "left_eye": null,
#       "right_eye": null
#     },
#     "face_confidence": 0.91
#   },
#   {
#     "emotion": {
#       "angry": 1.2956676845650485,
#       "disgust": 5.7616283181406046e-06,
#       "fear": 12.85612063742403,
#       "happy": 0.015984763238136513,
#       "sad": 0.0026525314513822207,
#       "surprise": 85.82948957857427,
#       "neutral": 8.012723833527952e-05
#     },
#     "dominant_emotion": "surprise",
#     "region": {
#       "x": 271,
#       "y": 326,
#       "w": 65,
#       "h": 65,
#       "left_eye": null,
# ...
